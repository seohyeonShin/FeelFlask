# %%
import json
import numpy as np
import pandas as pd

# %%
# 한번만 돌려야 합니다. 다시 돌리면 저장된 정보가 다 날아갑니다.
#dictionary = {}
#dictionary['feedback_info'] = []
#with open('./feedback/feedback.json', 'w') as fw:
#   json.dump(dictionary, fw)

# %%
with open('./feedback/feedback.json', 'r') as f:
    feedback = json.load(f)

# %%
feedback
# Out:
# {'feedback_info': [{'input_features': {'ABV': 41.0,
#     'boozy': 36.9,
#     'sweet': 100.0,
#     'sour': 45.0,
#     'bitter': 60.0,
#     'umami': 55.0,
#     'salty': 70.0,
#     'astringent': 54.0,
#     'perceived_t': 46.9069782200146,
#     'spicy': 95.0,
#     'herbal': 55.0,
#     'floral': 50.0,
#     'fruity': 35.0,
#     'nutty': 40.0,
#     'creamy': 75.0,
#     'smoky': 5.0,
#     'seed': 'hot chocolate'},
#    'output_ingredients': ['hot chocolate',
#     'milk',
#     'light rum',
#     'bourbon',
#     'vanilla extract'],
#    'output_amounts': [5.714285714285677,
#     5.714285714285677,
#     62.85714285714232,
#     62.85714285714232,
#     62.85714285714232],
#    'feedback_rating': 4},
#   {'input_features': {'ABV': 51.6,
#     'boozy': 46.440000000000005,
#     'sweet': 100.0,
#     'sour': 60.0,
#     'bitter': 55.0,
#     'umami': 45.0,
#     'salty': 65.0,
#     'astringent': 49.5,
#     'perceived_t': 46.87150518464567,
#     'spicy': 75.0,
#     'herbal': 45.0,
#     'floral': 45.0,
#     'fruity': 15.0,
#     'nutty': 55.0,
#     'creamy': 40.0,
#     'smoky': 60.0,
#     'seed': 'tabasco sauce'},
#    'output_ingredients': ['tabasco sauce', 'gin', 'bitters', 'orange peel'],
#    'output_amounts': [8.657999698193699,
#     95.2379966801305,
#     95.2379966801305,
#     0.00022996858355233538],
#    'feedback_rating': 4},
#   {'input_features': {'ABV': 47.0,
#     'boozy': 42.300000000000004,
#     'sweet': 55.0,
#     'sour': 70.0,
#     'bitter': 70.0,
#     'umami': 70.0,
#     'salty': 65.0,
#     'astringent': 63.0,
#     'perceived_t': 41.423826432957384,
#     'spicy': 55.0,
#     'herbal': 100.0,
#     'floral': 90.0,
#     'fruity': 55.0,
#     'nutty': 35.0,
#     'creamy': 70.0,
#     'smoky': 55.0,
#     'seed': 'cointreau'},
#    'output_ingredients': ['cointreau', 'lemon juice', 'ice'],
#    'output_amounts': [196.42773291860183,
#     0.00047430866969413673,
#     0.00047430866969413673],
#    'feedback_rating': 1},
#   {'input_features': {'ABV': 40.1,
#     'boozy': 36.09,
#     'sweet': 55.0,
#     'sour': 80.0,
#     'bitter': 70.0,
#     'umami': 75.0,
#     'salty': 65.0,
#     'astringent': 63.0,
#     'perceived_t': 35.332879989562265,
#     'spicy': 55.0,
#     'herbal': 95.0,
#     'floral': 100.0,
#     'fruity': 55.0,
#     'nutty': 40.0,
#     'creamy': 70.0,
#     'smoky': 55.0,
#     'seed': 'lillet blanc'},
#    'output_ingredients': ['lillet blanc',
#     'tequila',
#     'gin',
#     'bitters',
#     'lemon peel'],
#    'output_amounts': [49.88659427319774,
#     49.88659427319774,
#     49.88659427319774,
#     49.88659427319774,
#     0.00012045979360305891],
#    'feedback_rating': 4},
#   {'input_features': {'ABV': 45.3,
#     'boozy': 40.769999999999996,
#     'sweet': 55.0,
#     'sour': 80.0,
#     'bitter': 70.0,
#     'umami': 75.0,
#     'salty': 65.0,
#     'astringent': 63.0,
#     'perceived_t': 32.745938921600064,
#     'spicy': 55.0,
#     'herbal': 95.0,
#     'floral': 100.0,
#     'fruity': 55.0,
#     'nutty': 40.0,
#     'creamy': 70.0,
#     'smoky': 55.0,
#     'seed': 'mint'},
#    'output_ingredients': ['mint', 'lemon juice', 'angostura bitters'],
#    'output_amounts': [0.00047430866969413673,
#     0.00047430866969413673,
#     196.42773291860183],
#    'feedback_rating': 4},
#   {'input_features': {'ABV': 16.4,
#     'boozy': 14.76,
#     'sweet': 55.0,
#     'sour': 80.0,
#     'bitter': 70.0,
#     'umami': 75.0,
#     'salty': 65.0,
#     'astringent': 63.0,
#     'perceived_t': 45.15177522069197,
#     'spicy': 55.0,
#     'herbal': 95.0,
#     'floral': 100.0,
#     'fruity': 55.0,
#     'nutty': 40.0,
#     'creamy': 70.0,
#     'smoky': 55.0,
#     'seed': 'lavender'},
#    'output_ingredients': ['lavender',
#     'milk',
#     'orange juice',
#     'banana',
#     'cream'],
#    'output_amounts': [40.0, 40.0, 40.0, 40.0, 40.0],
#    'feedback_rating': 4},
#   {'input_features': {'ABV': 39.3,
#     'boozy': 35.37,
#     'sweet': 80.0,
#     'sour': 75.0,
#     'bitter': 80.0,
#     'umami': 65.0,
#     'salty': 75.0,
#     'astringent': 72.0,
#     'perceived_t': 45.511586787564326,
#     'spicy': 80.0,
#     'herbal': 90.0,
#     'floral': 90.0,
#     'fruity': 60.0,
#     'nutty': 30.0,
#     'creamy': 60.0,
#     'smoky': 15.0,
#     'seed': 'lavender'},
#    'output_ingredients': ['lavender', 'milk', 'light rum', 'vodka'],
#    'output_amounts': [8.657999698193699,
#     0.00022996858355233538,
#     95.2379966801305,
#     95.2379966801305],
#    'feedback_rating': 4},
#   {'input_features': {'ABV': 40.0,
#     'boozy': 36.0,
#     'sweet': 55.0,
#     'sour': 80.0,
#     'bitter': 70.0,
#     'umami': 75.0,
#     'salty': 65.0,
#     'astringent': 63.0,
#     'perceived_t': 33.22723673493161,
#     'spicy': 55.0,
#     'herbal': 80.0,
#     'floral': 85.0,
#     'fruity': 60.0,
#     'nutty': 40.0,
#     'creamy': 65.0,
#     'smoky': 55.0,
#     'seed': 'lavender'},
#    'output_ingredients': ['lavender', 'milk', 'light rum', 'vodka'],
#    'output_amounts': [8.657999698193699,
#     0.00022996858355233538,
#     95.2379966801305,
#     95.2379966801305],
#    'feedback_rating': 3},
#   {'input_features': {'ABV': 18.3,
#     'boozy': 16.470000000000002,
#     'sweet': 80.0,
#     'sour': 75.0,
#     'bitter': 80.0,
#     'umami': 60.0,
#     'salty': 75.0,
#     'astringent': 72.0,
#     'perceived_t': 36.23509874387087,
#     'spicy': 95.0,
#     'herbal': 85.0,
#     'floral': 80.0,
#     'fruity': 65.0,
#     'nutty': 35.0,
#     'creamy': 60.0,
#     'smoky': 20.0,
#     'seed': 'jägermeister'},
#    'output_ingredients': ['jägermeister',
#     'root beer',
#     'orange juice',
#     'cream'],
#    'output_amounts': [103.2258064516131,
#     32.25806451612907,
#     32.25806451612907,
#     32.25806451612907],
#    'feedback_rating': 4},
#   {'input_features': {'ABV': 46.4,
#     'boozy': 41.76,
#     'sweet': 75.0,
#     'sour': 75.0,
#     'bitter': 75.0,
#     'umami': 65.0,
#     'salty': 75.0,
#     'astringent': 67.5,
#     'perceived_t': 43.71202738498104,
#     'spicy': 85.0,
#     'herbal': 100.0,
#     'floral': 100.0,
#     'fruity': 60.0,
#     'nutty': 20.0,
#     'creamy': 60.0,
#     'smoky': 5.0,
#     'seed': 'lavender'},
#    'output_ingredients': ['lavender', 'milk', 'light rum', 'vodka'],
#    'output_amounts': [0.00023929136652582522,
#     0.00023929136652582522,
#     99.09888567706923,
#     99.09888567706923],
#    'feedback_rating': 5}]}

# %% [markdown]
# ##### Monitor feedback database
